# %%
import pandas as pd
import numpy as np


TRIP = pd.read_csv( "TRIP.csv")
TRIP.head(5)
# Out:
#                   Id           Departure Date  \
# 0   6079000000783579  2011-01-01 00:00:00.000
# 1  23079000000766048  2011-01-01 00:10:00.000
# 2  23079000000766035  2011-01-01 00:57:00.000
# 3   8079000000775501  2011-01-01 01:00:00.000
# 4   8079000000775497  2011-01-01 01:21:00.000
#
#                               Departure Hardour            Departure Region  \
# 0              Virtual Harbour (Central Region)              Central Region
# 1                                  Whiffen Head         Newfoundland Region
# 2                                  Whiffen Head         Newfoundland Region
# 3  Virtual Harbour (East Canadian Water Region)  East Canadian Water Region
# 4                               Halifax Harbour            Maritimes Region
#
#    Departure Latitude  Departure Longitude             Arrival Date  \
# 0           45.716667           -84.248611  2011-01-01 15:30:00.000
# 1           47.772784           -54.017180  2011-01-01 01:00:00.000
# ...

# %% [markdown]
# ### TABLE TRIP

# %%
len(TRIP.columns)
# Out:
# 16

# %%
columns = TRIP.columns

# %%
def explorData(df):
    columns =  df.columns
    print ("Nombre de colomnes :", len(columns))
    print ("######")
    for column in columns:
        print (column)
        print ("Type: ", df[column].dtype)
        if df[column].dtype != object:
            print ("Range : ", df[column].min(), " : ", df[column].max())
        else :
            print ("Typical value :", df[column].sample())
            
        print ("######")

# %%
explorData(TRIP)
# Out:
# Id
# Type:  int64
# Range :  1079000000761565  :  200079000000008559
# ######
# Departure Date
# Type:  object
# Typical value : 436932    2016-05-21 03:30:20.000
# Name: Departure Date, dtype: object
# ######
# Departure Hardour
# Type:  object
# Typical value : 256237    St. John's
# Name: Departure Hardour, dtype: object
# ######
# Departure Region
# Type:  object
# Typical value : 521407    East Canadian Water Region
# Name: Departure Region, dtype: object
# ######
# Departure Latitude
# Type:  float64
# Range :  -29.8833333333333  :  81.1833577777778
# ######
# Departure Longitude
# Type:  float64
# Range :  -180.0  :  179.166111111111
# ######
# Arrival Date
# Type:  object
# Typical value : 853459    2021-03-31 12:24:00.000
# Name: Arrival Date, dtype: object
# ######
# Arrival Hardour
# Type:  object
# Typical value : 515594    Virtual Harbour (West Canadian Water Region)
# Name: Arrival Hardour, dtype: object
# ######
# Arrival Region
# Type:  object
# ...

# %% [markdown]
# ### TABLE TRIP DETAIL

# %%
TRIP_DETAIL = pd.read_csv( "TRIP_DETAIL.csv")
TRIP_DETAIL.head(5)
# Out:
#                  Id  Rank Number                     Date  \
# 0  1079000000761565          1.0  2013-01-09 13:28:19.977
# 1  1079000000761565         99.0  2013-01-09 13:28:19.977
# 2  1079000000762036          1.0  2015-09-18 17:36:49.000
# 3  1079000000762036         99.0  2015-09-19 01:24:00.000
# 4  1079000000763481          1.0  2012-10-25 06:30:00.000
#
#                             Hardour               Region   Latitude  \
# 0                      Fishing East     Maritimes Region  44.450000
# 1                    St Pierre Bank  Newfoundland Region  45.666667
# 2                      Fishing East     Maritimes Region  44.450000
# 3                         Shelburne     Maritimes Region  43.683333
# 4  Chesterfield Inlet/Igluligaarjuk        Arctic Region  63.369071
#
#    Longitude Event Type
# 0 -58.783333  Departure
# 1 -56.000000    Arrival
# 2 -58.783333  Departure
# 3 -65.333333    Arrival
# 4 -90.873063  Departure

# %%
explorData(TRIP_DETAIL)
# Out:
# Id
# Type:  int64
# Range :  1079000000761565  :  200079000000008559
# ######
# Rank Number
# Type:  float64
# Range :  1.0  :  99.0
# ######
# Date
# Type:  object
# Typical value : 2507890    2018-05-28 13:23:00.000
# Name: Date, dtype: object
# ######
# Hardour
# Type:  object
# Typical value : 843546    Virtual Harbour (Newfoundland Region)
# Name: Hardour, dtype: object
# ######
# Region
# Type:  object
# Typical value : 7051316    Pacific Region
# Name: Region, dtype: object
# ######
# Latitude
# Type:  float64
# Range :  -29.8833333333333  :  84.31594
# ######
# Longitude
# Type:  float64
# Range :  -180.0  :  179.166111111111
# ######
# Event Type
# Type:  object
# Typical value : 6413475    Departure
# Name: Event Type, dtype: object
# ######
